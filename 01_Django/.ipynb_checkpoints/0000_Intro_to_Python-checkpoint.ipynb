# %% [markdown]
# <br>
# <img src="img/logo.png" width="80"/>
# <h1><center>The Complete Python Course</center></h1>
#
#
# Python is a **general-purpose, mordern, dynamic, robust, high level** and **interpreted** programming language. It is used in web development, machine learning, data science, creating software prototypes, and so on. Fortunately for beginners, Python has simple easy-to-use syntax. This makes Python an excellent language to learn to program for beginners.

# %% [markdown]
# ## Table of Contents
#
# 1. **Python Introduction**
#
#    1.1 [What is Programming?](http://localhost:8888/notebooks/Python_doc/01_Python_Introduction/000_What_is_Programming.ipynb)
#
#    1.2 [Python Programming](http://localhost:8888/notebooks/Python_doc/01_Python_Introduction/001_Python_Programming.ipynb)
#
#    1.3  [Getting Started](http://localhost:8888/notebooks/Python_doc/01_Python_Introduction/002_How_to_install_Python.ipynb)
#
#    1.4  [Jupyter Keyboard Shortcuts Practice](http://localhost:8888/notebooks/Python_doc/01_Python_Introduction/003_Jupyter_Keyboard_Shortcuts_Practice.ipynb)
#
#    1.5  [Hello World](http://localhost:8888/notebooks/Python_doc/01_Python_Introduction/004_Hello_World.ipynb)
#
#    1.6  [Keywords and Identifiers](http://localhost:8888/notebooks/Python_doc/01_Python_Introduction/005_Python_Keywords_and_Identifiers.ipynb)
#
#    1.7  [Statements, Indentation & Comments](http://localhost:8888/notebooks/Python_doc/01_Python_Introduction/006_Python_Statement_Indentation_Comments.ipynb)
#
#    1.8  [Python Variables & Constants](http://localhost:8888/notebooks/Python_doc/01_Python_Introduction/007_Python_Variables_%26_Constants.ipynb)
#
#    1.9  [Python Literals](http://localhost:8888/notebooks/Python_doc/01_Python_Introduction/008_Python_Literals.ipynb)
#
#    1.10  [Python Datatypes](http://localhost:8888/notebooks/Python_doc/01_Python_Introduction/009_Python_Data_Types.ipynb)
#
#    1.11 [Python Type Conversion](http://localhost:8888/notebooks/Python_doc/01_Python_Introduction/010_Python_Type_Conversion.ipynb)
#
#    1.12 [Python I/O and import](http://localhost:8888/notebooks/Python_doc/01_Python_Introduction/011_Python_Input_Output_Import.ipynb)
#
#    1.13 [Python Operators](http://localhost:8888/notebooks/Python_doc/01_Python_Introduction/012_Python_Operators.ipynb)
#
#    1.14 [Python Namespace & Scope](http://localhost:8888/notebooks/Python_doc/01_Python_Introduction/013_Python_Namespace_and_Scope.ipynb)
#
#    1.15 [Python Keyword List](http://localhost:8888/notebooks/Python_doc/01_Python_Introduction/Python_Keywords_List.ipynb)
#
#
#
#
# 2. **Python Data Types**
#
#   2.1 [Python Numbers](http://localhost:8888/notebooks/Python_doc/02_Python_Datatypes/001_Python_Numbers.ipynb)
#
#   2.2  [Python String](http://localhost:8888/notebooks/Python_doc/02_Python_Datatypes/002_Python_String.ipynb)
#
#   2.3  [Python List](http://localhost:8888/notebooks/Python_doc/02_Python_Datatypes/003_Python_List.ipynb)
#
#   2.4  [Python Tuple](http://localhost:8888/notebooks/Python_doc/02_Python_Datatypes/004_Python_Tuple.ipynb)
#
#   2.5  [Python Dictionary](http://localhost:8888/notebooks/Python_doc/02_Python_Datatypes/005_Python_Dictionary.ipynb)
#
#   2.6  [Python Sets](http://localhost:8888/notebooks/Python_doc/02_Python_Datatypes/006_Python_Sets.ipynb)
#
#
#
# 3. **Python Flow Control**
#
#   3.1 [Python Flow Control Statement](http://localhost:8888/notebooks/Python_doc/03_Python_Flow_Control/000_Python_Flow_Control_statement%20.ipynb)
#
#   3.2  [Python if statement](http://localhost:8888/notebooks/Python_doc/03_Python_Flow_Control/001_Python_if_statement.ipynb)
#
#   3.3  [Python if-else statement](http://localhost:8888/notebooks/Python_doc/03_Python_Flow_Control/002_Python_if_else_statement.ipynb)
#
#   3.4  [Python if-elif-else statement](http://localhost:8888/notebooks/Python_doc/03_Python_Flow_Control/003_Python_if_elif_else_statement%20.ipynb)
#
#   3.5  [Python Nested if statement](http://localhost:8888/notebooks/Python_doc/03_Python_Flow_Control/004_Python_Nested_if_statement.ipynb)
#
#   3.6  [Python for loop](http://localhost:8888/notebooks/Python_doc/03_Python_Flow_Control/005_Python_for_Loop.ipynb)
#
#   3.7  [Python while loop](http://localhost:8888/notebooks/Python_doc/03_Python_Flow_Control/006_Python_while_Loop.ipynb)
#
#   3.8  [Python break, continue & pass statements](http://localhost:8888/notebooks/Python_doc/03_Python_Flow_Control/007_Python_break_continue_pass_statements.ipynb)
#
#
# 4. **Python Functions**
#
#   4.1 [Python Functions intro.](http://localhost:8888/notebooks/Python_doc/04_Python_Functions/001_Python_Functions.ipynb)
#
#   4.2  [Global, Local & Nonlocal](http://localhost:8888/notebooks/Python_doc/04_Python_Functions/002_Python_Function_Global_Local_Nonlocal.ipynb)
#
#   4.3  [Global keyword](http://localhost:8888/notebooks/Python_doc/04_Python_Functions/003_Python_Function_global_Keywords.ipynb)
#
#   4.4  [Function Argument](http://localhost:8888/notebooks/Python_doc/04_Python_Functions/004_Python_Function_Arguments.ipynb)
#
#   4.5  [Function Recursion](http://localhost:8888/notebooks/Python_doc/04_Python_Functions/005_Python_Function_Recursion.ipynb)
#
#   4.6  [Function Anonymous](http://localhost:8888/notebooks/Python_doc/04_Python_Functions/006_Python_Function_Anonymous.ipynb)
#
#   4.7  [Function Module](http://localhost:8888/notebooks/Python_doc/04_Python_Functions/007_Python_Function_Module.ipynb)
#
#   4.8  [Function random Module](http://localhost:8888/notebooks/Python_doc/04_Python_Functions/008_Python_Function_random_Module.ipynb)
#
#   4.9  [Function math Module](http://localhost:8888/notebooks/Python_doc/04_Python_Functions/009_Python_Function_math_Module.ipynb.ipynb)
#
#   4.10  [Function Package](http://localhost:8888/notebooks/Python_doc/04_Python_Functions/010_Python_Function_Package.ipynb)
#
#   4.11 [Python Docstrings](http://localhost:8888/notebooks/Python_doc/04_Python_Functions/Python_Docstrings.ipynb)
#
#   4.12 [User-defined Function](http://localhost:8888/notebooks/Python_doc/04_Python_Functions/Python_User_defined_Functions.ipynb)
#
#
#
# 5. **Python Files**
#
#   5.1 [Python File I/O](http://localhost:8888/notebooks/Python_doc/05_Python_Files/001_Python_File_Input_Output.ipynb)
#
#   5.2 [Python File Directory](http://localhost:8888/notebooks/Python_doc/05_Python_Files/002_Python_File_Directory.ipynb)
#
#   5.3  [Python File Exception](http://localhost:8888/notebooks/Python_doc/05_Python_Files/003_Python_File_Exception.ipynb)
#
#   5.4  [Python Exceptions Handeling](http://localhost:8888/notebooks/Python_doc/05_Python_Files/004_Python_Exceptions_Handling.ipynb)
#
#   5.5  [Python User-defined Exceptions](http://localhost:8888/notebooks/Python_doc/05_Python_Files/005_Python_User_defined_Exceptions.ipynb)
#
#
# 6. **Python Object Class**
#
#   6.1 [Python OOPs Concepts](http://localhost:8888/notebooks/Python_doc/06_Python_Object_Class/001_Python_OOPs_Concepts.ipynb)
#
#   6.2  [Python Classes & Objects](http://localhost:8888/notebooks/Python_doc/06_Python_Object_Class/002_Python_Classes_and_Objects.ipynb)
#
#   6.3  [Python Inheritance](http://localhost:8888/notebooks/Python_doc/06_Python_Object_Class/003_Python_Inheritance.ipynb)
#
#   6.4  [Python Operator Overloading](http://localhost:8888/notebooks/Python_doc/06_Python_Object_Class/004_Python_Operator_Overloading.ipynb)
#
#
#
# 7. **Python Advanced Topics**
#
#   7.1 [Python Iterator](http://localhost:8888/notebooks/Python_doc/07_Python_Advanced_Topics/001_Python_Iterators.ipynb)
#
#   7.2  [Python Generator](http://localhost:8888/notebooks/Python_doc/07_Python_Advanced_Topics/002_Python_Generators.ipynb)
#
#   7.3  [Python Closure](http://localhost:8888/notebooks/Python_doc/07_Python_Advanced_Topics/003_Python_Closure.ipynb)
#
#   7.4  [Python Decorators](http://localhost:8888/notebooks/Python_doc/07_Python_Advanced_Topics/004_Python_Decorators.ipynb)
#
#   7.5  [Python Property](http://localhost:8888/notebooks/Python_doc/07_Python_Advanced_Topics/005_Python_Property.ipynb)
#
#   7.6  [Python RegEx](http://localhost:8888/notebooks/Python_doc/07_Python_Advanced_Topics/006_Python_RegEx.ipynb)
#
#
#
# 8. **Python Date & Time Module**
#
#   8.1 [Python datetime Module](http://localhost:8888/notebooks/Python_doc/08_Python_Date_Time_Module/001_Python_datetime_Module.ipynb)
#
#   8.2  [Python datetime.strftime()](http://localhost:8888/notebooks/Python_doc/08_Python_Date_Time_Module/002_Python_strftime%28%29.ipynb)
#
#   8.3  [Python datetime.strptime()](http://localhost:8888/notebooks/Python_doc/08_Python_Date_Time_Module/003_Python_strptime%28%29.ipynb)
#
#   8.4  [Current date & time](http://localhost:8888/notebooks/Python_doc/08_Python_Date_Time_Module/004_Python_current_date_and_time.ipynb)
#
#   8.5  [Get current time](http://localhost:8888/notebooks/Python_doc/08_Python_Date_Time_Module/005_Python_get_current_time.ipynb)
#
#   8.6  [Timestamp to datetime](http://localhost:8888/notebooks/Python_doc/08_Python_Date_Time_Module/006_Python_timestamp_to_datetime.ipynb)
#
#   8.7  [Python time Module](http://localhost:8888/notebooks/Python_doc/08_Python_Date_Time_Module/007_Python_time_Module.ipynb)
#
#   8.8  [Python time.sleep()](http://localhost:8888/notebooks/Python_doc/08_Python_Date_Time_Module/008_Python_sleep%28%29.ipynb)
#
#
#
# 9. **Python Numpy Module**
#
#   9.1 [Python Numpy](http://localhost:8888/notebooks/Python_doc/09_Python_NumPy_Module/001_Python_NumPy.ipynb)
#
#   9.2  [Python Numpy Array](http://localhost:8888/notebooks/Python_doc/09_Python_NumPy_Module/002_Python_NumPy_Array_Part1.ipynb)
#
#
#
# 10. **Python Pandas Module**
#
#   10.1 [Python Pandas Dataframe](http://localhost:8888/notebooks/Python_doc/10_Python_Pandas_Module/001_Python_Pandas_DataFrame.ipynb)
#
#   10.2  [Python Pandas Exercise 1](http://localhost:8888/notebooks/Python_doc/10_Python_Pandas_Module/002_Python_Pandas_Exercise_1.ipynb)
#
#   10.3  [Python Pandas Exercise 2](http://localhost:8888/notebooks/Python_doc/10_Python_Pandas_Module/003_Python_Pandas_Exercise_2.ipynb)
#
#
#
# 11. **Python Matplotlib Module**
#
#   11.1 [Basic Graph](http://localhost:8888/notebooks/Python_doc/11_Python_Matplotlib_Module/Intro_Data_Visualization.ipynb)
#
#   11.2  [Python Matplotlib Exercise 1](http://localhost:8888/notebooks/Python_doc/11_Python_Matplotlib_Module/002_Python_Matplotlib_Exercise_1.ipynb)
#
#   11.3  [Python Matplotlib Exercise 2](http://localhost:8888/notebooks/Python_doc/11_Python_Matplotlib_Module/003_Python_Matplotlib_Exercise_2.ipynb)
#
#
#
# 12. **Python Seaborn Module**
#
#   12.1 [Python Seaborn_Loading_Dataset](http://localhost:8888/notebooks/Python_doc/12_Python_Seaborn_Module/001_Seaborn_Loading_Dataset.ipynb)
#
#   12.2  [Python Seaborn_Controlling_Aesthetics](http://localhost:8888/notebooks/Python_doc/12_Python_Seaborn_Module/002_Seaborn_Controlling_Aesthetics.ipynb)
#
#   12.3  [Python Matplotlib_vs_Seaborn](http://localhost:8888/notebooks/Python_doc/12_Python_Seaborn_Module/003_Matplotlib_vs_Seaborn.ipynb)
#
#   12.4  [Python Seaborn_Color_Palettes](http://localhost:8888/notebooks/Python_doc/12_Python_Seaborn_Module/004_Seaborn_Color_Palettes.ipynb)
#
#   12.5  [Python Seaborn_LM_Plot_and_Reg_Plot](http://localhost:8888/notebooks/Python_doc/12_Python_Seaborn_Module/005_Seaborn_LM_Plot_and_Reg_Plot.ipynb)
#
#   12.6  [Python Seaborn_Scatter_Plot_and_Joint_Plot](http://localhost:8888/notebooks/Python_doc/12_Python_Seaborn_Module/006_Seaborn_Scatter_Plot_and_Joint_Plot.ipynb)
#
#   12.7  [Python Seaborn_Additional_Regression_Plots](http://localhost:8888/notebooks/Python_doc/12_Python_Seaborn_Module/007_Seaborn_Additional_Regression_Plots.ipynb)
#
#   12.8  [Python Seaborn_Distribution_Plots](http://localhost:8888/notebooks/Python_doc/12_Python_Seaborn_Module/008_Seaborn_Distribution_Plots.ipynb)
#
#   12.9  [Python Seaborn_Categorical_Swarm_Plot](http://localhost:8888/notebooks/Python_doc/12_Python_Seaborn_Module/009_Seaborn_Categorical_Swarm_Plot.ipynb)
#
#   12.10  [Python Seaborn_Categorical_Strip_Plot](http://localhost:8888/notebooks/Python_doc/12_Python_Seaborn_Module/010_Seaborn_Categorical_Strip_Plot.ipynb)
#
#   12.11  [Python Seaborn_Categorical_Box_Plot](http://localhost:8888/notebooks/Python_doc/12_Python_Seaborn_Module/011_Seaborn_Categorical_Box_Plot.ipynb)
#
#   12.12 [Python Seaborn_Categorical_Violin_Plot](http://localhost:8888/notebooks/Python_doc/12_Python_Seaborn_Module/012_Seaborn_Categorical_Violin_Plot.ipynb)
#
#   12.13 [Python Seaborn_Categorical_Bar_Plot_Point_Plot_and_Count_Plot](http://localhost:8888/notebooks/Python_doc/12_Python_Seaborn_Module/013_Seaborn_Categorical_Bar_Plot_Point_Plot_and_Count_Plot.ipynb)
#
#   12.14 [Python Seaborn_Categorical_Factor_Plot](http://localhost:8888/notebooks/Python_doc/12_Python_Seaborn_Module/014_Seaborn_Categorical_Factor_Plot.ipynb)
#
#   12.15 [Python Seaborn_TimeSeries_and_LetterValue_Plot](http://localhost:8888/notebooks/Python_doc/12_Python_Seaborn_Module/015_Seaborn_TimeSeries_and_LetterValue_Plot.ipynb)
#
#   12.16 [Python Seaborn_PairGrid_Plot](http://localhost:8888/notebooks/Python_doc/12_Python_Seaborn_Module/016_Seaborn_PairGrid_Plot.ipynb)
#
#   12.17 [Python Seaborn_FacetGrid_Plot](http://localhost:8888/notebooks/Python_doc/12_Python_Seaborn_Module/017_Seaborn_FacetGrid_Plot.ipynb)
#
#   12.18 [Python Seaborn_Heat_Map](http://localhost:8888/notebooks/Python_doc/12_Python_Seaborn_Module/018_Seaborn_Heat_Map.ipynb)
#
#   12.19 [Python Seaborn_Cluster_Map](http://localhost:8888/notebooks/Python_doc/12_Python_Seaborn_Module/019_Seaborn_Cluster_Map.ipynb)
#
#
# 13. **Introduction to Image Processing**
#
#     13.1 [Introduction to OpenCV](http://localhost:8888/notebooks/Python_doc/13_Image_Processing/Image_Processing.ipynb#1)
#
#     13.2 [Reading an Image](http://localhost:8888/notebooks/Python_doc/13_Image_Processing/Image_Processing.ipynb#2)
#
#     13.3. [Examine the Image](http://localhost:8888/notebooks/Python_doc/13_Image_Processing/Image_Processing.ipynb#3)
#
#     13.4. [Drawing Shapes](http://localhost:8888/notebooks/Python_doc/13_Image_Processing/Image_Processing.ipynb#4)
#
#     13.5 [Drawing a Line](http://localhost:8888/notebooks/Python_doc/13_Image_Processing/Image_Processing.ipynb#11)
#
#     13.6 [Drawing a Rectangle](http://localhost:8888/notebooks/Python_doc/13_Image_Processing/Image_Processing.ipynb#12)
#
#     13.7 [Drawing a Circle](http://localhost:8888/notebooks/Python_doc/13_Image_Processing/Image_Processing.ipynb#13)
#
#     13.8 [Drawing a Ellipse](http://localhost:8888/notebooks/Python_doc/13_Image_Processing/Image_Processing.ipynb#14)
#
#     13.9 [Drawing a Polygon](http://localhost:8888/notebooks/Python_doc/13_Image_Processing/Image_Processing.ipynb#15)
#
#     13.10 [Drawing a Polygon](http://localhost:8888/notebooks/Python_doc/13_Image_Processing/Image_Processing.ipynb#16)
#
#     13.11 [Putting the Text on the Image](http://localhost:8888/notebooks/Python_doc/13_Image_Processing/Image_Processing.ipynb#17)
#
#     13.12 [Saving the Image](http://localhost:8888/notebooks/Python_doc/13_Image_Processing/Image_Processing.ipynb#5)
#
#     13.13 [Grayscaling](http://localhost:8888/notebooks/Python_doc/13_Image_Processing/Image_Processing.ipynb#6)
#
#     13.14 [Thresholding, Binarization & Adaptive Thresholding](http://localhost:8888/notebooks/Python_doc/13_Image_Processing/Image_Processing.ipynb#7)
#
#     13.15 [Arithmetic Operations on Images](http://localhost:8888/notebooks/Python_doc/13_Image_Processing/Image_Processing.ipynb#8)
#
#     13.16 [Image Addition](http://localhost:8888/notebooks/Python_doc/13_Image_Processing/Image_Processing.ipynb#18)
#
#     13.17 [Image Subtraction](http://localhost:8888/notebooks/Python_doc/13_Image_Processing/Image_Processing.ipynb#19)
#
#     13.18 [Bitwise Operations](http://localhost:8888/notebooks/Python_doc/13_Image_Processing/Image_Processing.ipynb#20)
#
#     13.19 [Image Enhancement Methods](http://localhost:8888/notebooks/Python_doc/13_Image_Processing/Image_Processing.ipynb#9)
#
#     13.20 [Smoothing with Gaussian Filter](http://localhost:8888/notebooks/Python_doc/13_Image_Processing/Image_Processing.ipynb#21)
#
#     13.21 [Noise Removal](http://localhost:8888/notebooks/Python_doc/13_Image_Processing/Image_Processing.ipynb#22)
#
#     13.22 [Color Filtering](http://localhost:8888/notebooks/Python_doc/13_Image_Processing/Image_Processing.ipynb#10)
#
#
# 14. **AI/ML Algorithms**
#
#     14.1 [Intro. AI/ML](http://localhost:8888/notebooks/Python_doc/14_AI_ML_Algorithms/Intro_AI_ML.ipynb)
#
#     14.2 [Linear Regression](http://localhost:8888/notebooks/Python_doc/14_AI_ML_Algorithms/ML_Algorithms_1-2.ipynb)
#
#     14.3 [Logistic Regression](http://localhost:8888/notebooks/Python_doc/14_AI_ML_Algorithms/ML_Algorithms_1-2.ipynb)
#
#     14.4 [Decision Tree](http://localhost:8888/notebooks/Python_doc/14_AI_ML_Algorithms/ML_Algorithms_3-4.ipynb)
#
#     14.5 [Random Forest](http://localhost:8888/notebooks/Python_doc/14_AI_ML_Algorithms/ML_Algorithms_3-4.ipynb)
#
#     14.6 [KNN Theory And Practical](http://localhost:8888/notebooks/Python_doc/14_AI_ML_Algorithms/KNN%20Theory%20%26%20Practical.ipynb)
#
#
# 15. **Natural language Processing**
#
#     15.1 [Getting Started With NLP](http://localhost:8888/notebooks/Python_doc/15_NLP/1%20Getting%20Started%20With%20NLP.ipynb)
#
#     15.2 [Tokenization](http://localhost:8888/notebooks/Python_doc/15_NLP/2%20Tokenization.ipynb)
#
#     15.3 [Stemming & It's types](http://localhost:8888/notebooks/Python_doc/15_NLP/3%20Stemming%20%26%20It's%20types.ipynb)
#
#     15.4 [Lemmatization](http://localhost:8888/notebooks/Python_doc/15_NLP/4%20Lemmatization.ipynb)
#
#     15.5 [Stop words](http://localhost:8888/notebooks/Python_doc/15_NLP/5%20stop%20words.ipynb)
#
#     15.6 [Part of Speech Tagging](http://localhost:8888/notebooks/Python_doc/15_NLP/6%20Part%20of%20Speech%20Tagging.ipynb)
#
#     15.7 [Vectorization](http://localhost:8888/notebooks/Python_doc/15_NLP/7%20Vectorization.ipynb)
#
#     15.8 [NER (Name Entity Recognition)](http://localhost:8888/notebooks/Python_doc/15_NLP/8%20NER%20(Name%20Entity%20Recognition).ipynb)
#
#     15.9 [Excersise](http://localhost:8888/notebooks/Python_doc/15_NLP/Project%20(KNN%20%2B%20NLP).ipynb)
#
#
#
# 16. **Scraping**
#
#     16.1 [python beautifulsoup Module](http://localhost:8888/notebooks/Python_doc/16_Scraping/web_scraping.ipynb)
#
#
#
# 17. **API**
#
#     17.1 [Flask API](http://localhost:8888/notebooks/Python_doc/17_API/Flask.ipynb)
#
#
# 18. **Deployment**
#
#     18.1 [GIT](http://localhost:8888/notebooks/Python_doc/18_Deployment/Git.ipynb)
#
#     18.2 [Docker](http://localhost:8888/notebooks/Python_doc/18_Deployment/Docker.ipynb)

# %% [markdown]
# ## About Python Programming
#
# * **Free and open-source** - You can freely use and distribute Python, even for commercial use.
# * **Easy to learn** - Python has a very simple and elegant syntax. It's much easier to read and write Python programs compared to other languages like C++, Java, C#.
# * **Portable** - You can move Python programs from one platform to another, and run it without any changes.

# %% [markdown]
# ## Why Learn Python?
#
# * Python is easy to learn. Its syntax is easy and code is very readable.
# * Python has a lot of applications. It's used for developing web applications, data science, rapid application development, and so on.
# * Python allows you to write programs in fewer lines of code than most of the programming languages.
# * The popularity of Python is growing rapidly. Now it's one of the most popular programming languages.

# %% [markdown]
# ## How to learn Python?
#
# * **Python classes** - We provide step by step Python tutorials, examples, and references. **[Get started with Python]()**.
# * **Official Python tutorial** - Might be hard to follow and understand for beginners. Visit the official **[Python tutorial](https://docs.python.org/3/tutorial/)**.
# * **Write a lot of Python code** - The only way you can learn programming is by writing a lot of code.

# %% [markdown]
# ## Python Resources
#
# * **[Python Online Compiler 1](https://www.w3schools.com/python/trypython.asp?filename=demo_compiler)**
# * **[Python Online Compiler 2](https://www.tutorialspoint.com/execute_python_online.php)**
