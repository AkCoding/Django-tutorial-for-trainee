# %% [markdown]
# <br>
# <img src="logo.png" width="500"/>
# <h1><center>The Complete Django Course</center></h1>
#
#
# Python is a **general-purpose, mordern, dynamic, robust, high level** and **interpreted** programming language. It is used in web development, machine learning, data science, creating software prototypes, and so on. Fortunately for beginners, Python has simple easy-to-use syntax. This makes Python an excellent language to learn to program for beginners.

# %% [markdown]
# ## Table of Contents
#
# 1. **Python Introduction**
#
#    1.1 [What is Programming?](01_Python_Introduction/000_What_is_Programming.ipynb)
#
#    1.2 [Python Programming](01_Python_Introduction/001_Python_Programming.ipynb)
#
#    1.3  [Getting Started](01_Python_Introduction/002_How_to_install_Python.ipynb)
#
#    1.4  [Jupyter Keyboard Shortcuts Practice](01_Python_Introduction/003_Jupyter_Keyboard_Shortcuts_Practice.ipynb)
#
#    1.5  [Hello World](01_Python_Introduction/004_Hello_World.ipynb)
#
#    1.6  [Keywords and Identifiers](01_Python_Introduction/005_Python_Keywords_and_Identifiers.ipynb)
#
#    1.7  [Statements, Indentation & Comments](01_Python_Introduction/006_Python_Statement_Indentation_Comments.ipynb)
#
#    1.8  [Python Variables & Constants](01_Python_Introduction/007_Python_Variables_%26_Constants.ipynb)
#
#    1.9  [Python Literals](01_Python_Introduction/008_Python_Literals.ipynb)
#
#    1.10  [Python Datatypes](01_Python_Introduction/009_Python_Data_Types.ipynb)
#
#    1.11 [Python Type Conversion](01_Python_Introduction/010_Python_Type_Conversion.ipynb)
#
#    1.12 [Python I/O and import](01_Python_Introduction/011_Python_Input_Output_Import.ipynb)
#
#    1.13 [Python Operators](01_Python_Introduction/012_Python_Operators.ipynb)
#
#    1.14 [Python Namespace & Scope](01_Python_Introduction/013_Python_Namespace_and_Scope.ipynb)
#
#    1.15 [Python Keyword List](01_Python_Introduction/Python_Keywords_List.ipynb)
#
#
#
#
# 2. **Python Data Types**
#
#   2.1 [Python Numbers](01_Python_Introduction/001_Python_Numbers.ipynb)
#
#   2.2  [Python String](01_Python_Introduction/002_Python_String.ipynb)
#
#   2.3  [Python List](01_Python_Introduction/003_Python_List.ipynb)
#
#   2.4  [Python Tuple](01_Python_Introduction/004_Python_Tuple.ipynb)
#
#   2.5  [Python Dictionary](01_Python_Introduction/005_Python_Dictionary.ipynb)
#
#   2.6  [Python Sets](01_Python_Introduction/006_Python_Sets.ipynb)
#
#
#
# 3. **Python Flow Control**
#
#   3.1 [Python Flow Control Statement](01_Python_Introduction/000_Python_Flow_Control_statement%20.ipynb)
#
#   3.2  [Python if statement](01_Python_Introduction/001_Python_if_statement.ipynb)
#
#   3.3  [Python if-else statement](01_Python_Introduction/002_Python_if_else_statement.ipynb)
#
#   3.4  [Python if-elif-else statement](01_Python_Introduction/003_Python_if_elif_else_statement%20.ipynb)
#
#   3.5  [Python Nested if statement](01_Python_Introduction/004_Python_Nested_if_statement.ipynb)
#
#   3.6  [Python for loop](01_Python_Introduction/005_Python_for_Loop.ipynb)
#
#   3.7  [Python while loop](01_Python_Introduction/006_Python_while_Loop.ipynb)
#
#   3.8  [Python break, continue & pass statements](01_Python_Introduction/007_Python_break_continue_pass_statements.ipynb)
#
#
# 4. **Python Functions**
#
#   4.1 [Python Functions intro.](01_Python_Introduction/001_Python_Functions.ipynb)
#
#   4.2  [Global, Local & Nonlocal](01_Python_Introduction/002_Python_Function_Global_Local_Nonlocal.ipynb)
#
#   4.3  [Global keyword](01_Python_Introduction/003_Python_Function_global_Keywords.ipynb)
#
#   4.4  [Function Argument](01_Python_Introduction/004_Python_Function_Arguments.ipynb)
#
#   4.5  [Function Recursion](01_Python_Introduction/005_Python_Function_Recursion.ipynb)
#
#   4.6  [Function Anonymous](01_Python_Introduction/006_Python_Function_Anonymous.ipynb)
#
#   4.7  [Function Module](01_Python_Introduction/007_Python_Function_Module.ipynb)
#
#   4.8  [Function random Module](01_Python_Introduction/008_Python_Function_random_Module.ipynb)
#
#   4.9  [Function math Module](01_Python_Introduction/009_Python_Function_math_Module.ipynb.ipynb)
#
#   4.10  [Function Package](01_Python_Introduction/010_Python_Function_Package.ipynb)
#
#   4.11 [Python Docstrings](01_Python_Introduction/Python_Docstrings.ipynb)
#
#   4.12 [User-defined Function](01_Python_Introduction/Python_User_defined_Functions.ipynb)
#
#
#
# 5. **Python Files**
#
#   5.1 [Python File I/O](01_Python_Introduction/001_Python_File_Input_Output.ipynb)
#
#   5.2 [Python File Directory](01_Python_Introduction/002_Python_File_Directory.ipynb)
#
#   5.3  [Python File Exception](01_Python_Introduction/003_Python_File_Exception.ipynb)
#
#   5.4  [Python Exceptions Handeling](01_Python_Introduction/004_Python_Exceptions_Handling.ipynb)
#
#   5.5  [Python User-defined Exceptions](01_Python_Introduction/005_Python_User_defined_Exceptions.ipynb)
#
#
# 6. **Python Object Class**
#
#   6.1 [Python OOPs Concepts](01_Python_Introduction/001_Python_OOPs_Concepts.ipynb)
#
#   6.2  [Python Classes & Objects](01_Python_Introduction/002_Python_Classes_and_Objects.ipynb)
#
#   6.3  [Python Inheritance](01_Python_Introduction/003_Python_Inheritance.ipynb)
#
#   6.4  [Python Operator Overloading](01_Python_Introduction/004_Python_Operator_Overloading.ipynb)
#
#
#
# 7. **Python Advanced Topics**
#
#   7.1 [Python Iterator](01_Python_Introduction/001_Python_Iterators.ipynb)
#
#   7.2  [Python Generator](01_Python_Introduction/002_Python_Generators.ipynb)
#
#   7.3  [Python Closure](01_Python_Introduction/003_Python_Closure.ipynb)
#
#   7.4  [Python Decorators](01_Python_Introduction/004_Python_Decorators.ipynb)
#
#   7.5  [Python Property](01_Python_Introduction/005_Python_Property.ipynb)
#
#   7.6  [Python RegEx](01_Python_Introduction/006_Python_RegEx.ipynb)
#
#
#
# 8. **Python Date & Time Module**
#
#   8.1 [Python datetime Module](01_Python_Introduction/001_Python_datetime_Module.ipynb)
#
#   8.2  [Python datetime.strftime()](01_Python_Introduction/002_Python_strftime%28%29.ipynb)
#
#   8.3  [Python datetime.strptime()](01_Python_Introduction/003_Python_strptime%28%29.ipynb)
#
#   8.4  [Current date & time](01_Python_Introduction/004_Python_current_date_and_time.ipynb)
#
#   8.5  [Get current time](01_Python_Introduction/005_Python_get_current_time.ipynb)
#
#   8.6  [Timestamp to datetime](01_Python_Introduction/006_Python_timestamp_to_datetime.ipynb)
#
#   8.7  [Python time Module](01_Python_Introduction/007_Python_time_Module.ipynb)
#
#   8.8  [Python time.sleep()](01_Python_Introduction/008_Python_sleep%28%29.ipynb)
#
#
#
# 9. **Python Numpy Module**
#
#   9.1 [Python Numpy](01_Python_Introduction/001_Python_NumPy.ipynb)
#
#   9.2  [Python Numpy Array](01_Python_Introduction/002_Python_NumPy_Array_Part1.ipynb)
#
#
#
# 10. **Python Pandas Module**
#
#   10.1 [Python Pandas Dataframe](01_Python_Introduction/001_Python_Pandas_DataFrame.ipynb)
#
#   10.2  [Python Pandas Exercise 1](01_Python_Introduction/002_Python_Pandas_Exercise_1.ipynb)
#
#   10.3  [Python Pandas Exercise 2](01_Python_Introduction/003_Python_Pandas_Exercise_2.ipynb)
#
#
#
# 11. **Python Matplotlib Module**
#
#   11.1 [Basic Graph](01_Python_Introduction/Intro_Data_Visualization.ipynb)
#
#   11.2  [Python Matplotlib Exercise 1](01_Python_Introduction/002_Python_Matplotlib_Exercise_1.ipynb)
#
#   11.3  [Python Matplotlib Exercise 2](01_Python_Introduction/003_Python_Matplotlib_Exercise_2.ipynb)
#
#
#
# 12. **Python Seaborn Module**
#
#   12.1 [Python Seaborn_Loading_Dataset](01_Python_Introduction/001_Seaborn_Loading_Dataset.ipynb)
#
#   12.2  [Python Seaborn_Controlling_Aesthetics](01_Python_Introduction/002_Seaborn_Controlling_Aesthetics.ipynb)
#
#   12.3  [Python Matplotlib_vs_Seaborn](01_Python_Introduction/003_Matplotlib_vs_Seaborn.ipynb)
#
#   12.4  [Python Seaborn_Color_Palettes](01_Python_Introduction/004_Seaborn_Color_Palettes.ipynb)
#
#   12.5  [Python Seaborn_LM_Plot_and_Reg_Plot](01_Python_Introduction/005_Seaborn_LM_Plot_and_Reg_Plot.ipynb)
#
#   12.6  [Python Seaborn_Scatter_Plot_and_Joint_Plot](01_Python_Introduction/006_Seaborn_Scatter_Plot_and_Joint_Plot.ipynb)
#
#   12.7  [Python Seaborn_Additional_Regression_Plots](01_Python_Introduction/007_Seaborn_Additional_Regression_Plots.ipynb)
#
#   12.8  [Python Seaborn_Distribution_Plots](01_Python_Introduction/008_Seaborn_Distribution_Plots.ipynb)
#
#   12.9  [Python Seaborn_Categorical_Swarm_Plot](01_Python_Introduction/009_Seaborn_Categorical_Swarm_Plot.ipynb)
#
#   12.10  [Python Seaborn_Categorical_Strip_Plot](01_Python_Introduction/010_Seaborn_Categorical_Strip_Plot.ipynb)
#
#   12.11  [Python Seaborn_Categorical_Box_Plot](01_Python_Introduction/011_Seaborn_Categorical_Box_Plot.ipynb)
#
#   12.12 [Python Seaborn_Categorical_Violin_Plot](01_Python_Introduction/012_Seaborn_Categorical_Violin_Plot.ipynb)
#
#   12.13 [Python Seaborn_Categorical_Bar_Plot_Point_Plot_and_Count_Plot](01_Python_Introduction/013_Seaborn_Categorical_Bar_Plot_Point_Plot_and_Count_Plot.ipynb)
#
#   12.14 [Python Seaborn_Categorical_Factor_Plot](01_Python_Introduction/014_Seaborn_Categorical_Factor_Plot.ipynb)
#
#   12.15 [Python Seaborn_TimeSeries_and_LetterValue_Plot](01_Python_Introduction/015_Seaborn_TimeSeries_and_LetterValue_Plot.ipynb)
#
#   12.16 [Python Seaborn_PairGrid_Plot](01_Python_Introduction/016_Seaborn_PairGrid_Plot.ipynb)
#
#   12.17 [Python Seaborn_FacetGrid_Plot](01_Python_Introduction/017_Seaborn_FacetGrid_Plot.ipynb)
#
#   12.18 [Python Seaborn_Heat_Map](01_Python_Introduction/018_Seaborn_Heat_Map.ipynb)
#
#   12.19 [Python Seaborn_Cluster_Map](01_Python_Introduction/019_Seaborn_Cluster_Map.ipynb)
#
#
# 13. **Introduction to Image Processing**
#
#     13.1 [Introduction to OpenCV](01_Python_Introduction/Image_Processing.ipynb#1)
#
#     13.2 [Reading an Image](01_Python_Introduction/Image_Processing.ipynb#2)
#
#     13.3. [Examine the Image](01_Python_Introduction/Image_Processing.ipynb#3)
#
#     13.4. [Drawing Shapes](01_Python_Introduction/Image_Processing.ipynb#4)
#
#     13.5 [Drawing a Line](01_Python_Introduction/Image_Processing.ipynb#11)
#
#     13.6 [Drawing a Rectangle](01_Python_Introduction/Image_Processing.ipynb#12)
#
#     13.7 [Drawing a Circle](01_Python_Introduction/Image_Processing.ipynb#13)
#
#     13.8 [Drawing a Ellipse](01_Python_Introduction/Image_Processing.ipynb#14)
#
#     13.9 [Drawing a Polygon](01_Python_Introduction/Image_Processing.ipynb#15)
#
#     13.10 [Drawing a Polygon](01_Python_Introduction/Image_Processing.ipynb#16)
#
#     13.11 [Putting the Text on the Image](01_Python_Introduction/Image_Processing.ipynb#17)
#
#     13.12 [Saving the Image](01_Python_Introduction/Image_Processing.ipynb#5)
#
#     13.13 [Grayscaling](01_Python_Introduction/Image_Processing.ipynb#6)
#
#     13.14 [Thresholding, Binarization & Adaptive Thresholding](01_Python_Introduction/Image_Processing.ipynb#7)
#
#     13.15 [Arithmetic Operations on Images](01_Python_Introduction/Image_Processing.ipynb#8)
#
#     13.16 [Image Addition](01_Python_Introduction/Image_Processing.ipynb#18)
#
#     13.17 [Image Subtraction](01_Python_Introduction/Image_Processing.ipynb#19)
#
#     13.18 [Bitwise Operations](01_Python_Introduction/Image_Processing.ipynb#20)
#
#     13.19 [Image Enhancement Methods](01_Python_Introduction/Image_Processing.ipynb#9)
#
#     13.20 [Smoothing with Gaussian Filter](13_Image_Processing/Image_Processing.ipynb#21)
#
#     13.21 [Noise Removal](01_Python_Introduction/Image_Processing.ipynb#22)
#
#     13.22 [Color Filtering](01_Python_Introduction/Image_Processing.ipynb#10)
#
#
# 14. **AI/ML Algorithms**
#
#     14.1 [Intro. AI/ML](01_Python_Introduction/Intro_AI_ML.ipynb)
#
#     14.2 [Linear Regression](01_Python_Introduction/ML_Algorithms_1-2.ipynb)
#
#     14.3 [Logistic Regression](01_Python_Introduction/ML_Algorithms_1-2.ipynb)
#
#     14.4 [Decision Tree](01_Python_Introduction/ML_Algorithms_3-4.ipynb)
#
#     14.5 [Random Forest](01_Python_Introduction/ML_Algorithms_3-4.ipynb)
#
#     14.6 [KNN Theory And Practical](01_Python_Introduction/KNN%20Theory%20%26%20Practical.ipynb)
#
#
# 15. **Natural language Processing**
#
#     15.1 [Getting Started With NLP](01_Python_Introduction/1%20Getting%20Started%20With%20NLP.ipynb)
#
#     15.2 [Tokenization](01_Python_Introduction/2%20Tokenization.ipynb)
#
#     15.3 [Stemming & It's types](01_Python_Introduction/3%20Stemming%20%26%20It's%20types.ipynb)
#
#     15.4 [Lemmatization](01_Python_Introduction/4%20Lemmatization.ipynb)
#
#     15.5 [Stop words](01_Python_Introduction/5%20stop%20words.ipynb)
#
#     15.6 [Part of Speech Tagging](01_Python_Introduction/6%20Part%20of%20Speech%20Tagging.ipynb)
#
#     15.7 [Vectorization](01_Python_Introduction/7%20Vectorization.ipynb)
#
#     15.8 [NER (Name Entity Recognition)](01_Python_Introduction/8%20NER%20(Name%20Entity%20Recognition).ipynb)
#
#     15.9 [Excersise](01_Python_Introduction/Project%20(KNN%20%2B%20NLP).ipynb)
#
#
# 16. **API**
#
#     16.1 [Flask API](01_Python_Introduction/Flask.ipynb)
#
#
# 17. **Deployment**
#
#     17.1 [GIT](01_Python_Introduction/Git.ipynb)
#
#     17.2 [Docker](01_Python_Introduction/Docker.ipynb)
#
# 18. **Scraping**
#
#     18.1 [python beautifulsoup Module](01_Python_Introduction/web_scraping.ipynb)

# %% [markdown]
# ## About Python Programming
#
# * **Free and open-source** - You can freely use and distribute Python, even for commercial use.
# * **Easy to learn** - Python has a very simple and elegant syntax. It's much easier to read and write Python programs compared to other languages like C++, Java, C#.
# * **Portable** - You can move Python programs from one platform to another, and run it without any changes.

# %% [markdown]
# ## Why Learn Python?
#
# * Python is easy to learn. Its syntax is easy and code is very readable.
# * Python has a lot of applications. It's used for developing web applications, data science, rapid application development, and so on.
# * Python allows you to write programs in fewer lines of code than most of the programming languages.
# * The popularity of Python is growing rapidly. Now it's one of the most popular programming languages.

# %% [markdown]
# ## How to learn Python?
#
# * **Python classes** - We provide step by step Python tutorials, examples, and references. **[Get started with Python]()**.
# * **Official Python tutorial** - Might be hard to follow and understand for beginners. Visit the official **[Python tutorial](https://docs.python.org/3/tutorial/)**.
# * **Write a lot of Python code** - The only way you can learn programming is by writing a lot of code.

# %% [markdown]
# ## Python Resources
#
# * **[Python Online Compiler 1](https://www.w3schools.com/python/trypython.asp?filename=demo_compiler)**
# * **[Python Online Compiler 2](https://www.tutorialspoint.com/execute_python_online.php)**
